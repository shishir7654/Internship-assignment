# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("internbuddy_data_v1.csv")

# %%
df.head().T
# Out:
#                                                      0  \
# Application_ID                                  ML0001
# Current City                                 Bangalore
# Python (out of 3)                                    0
# R Programming (out of 3)                             2
# Deep Learning (out of 3)                             0
# PHP (out of 3)                                       2
# MySQL (out of 3)                                     0
# HTML (out of 3)                                      2
# CSS (out of 3)                                       3
# JavaScript (out of 3)                                2
# Unnamed: 10                                        NaN
# AJAX (out of 3)                                      0
# Bootstrap (out of 3)                                 2
# MongoDB (out of 3)                                   0
# Node.js (out of 3)                                   0
# ReactJS (out of 3)                                   0
# Other skills                             R Programming
# Degree                      Bachelor of Science (B.Sc)
# Stream                                     Mathematics
# Current Year Of Graduation                        2017
# Performance_PG                                     NaN
# Performance_UG                                     NaN
# Performance_12                                     NaN
# Performance_10                                     NaN
#
#                                                                             1  \
# Application_ID                                                         ML0002
# Current City                                                        Bangalore
# Python (out of 3)                                                           2
# R Programming (out of 3)                                                    0
# Deep Learning (out of 3)                                                    0
# PHP (out of 3)                                                              2
# MySQL (out of 3)                                                            2
# HTML (out of 3)                                                             2
# CSS (out of 3)                                                              2
# JavaScript (out of 3)                                                       2
# Unnamed: 10                                                               NaN
# AJAX (out of 3)                                                             0
# Bootstrap (out of 3)                                                        0
# MongoDB (out of 3)                                                          0
# Node.js (out of 3)                                                          0
# ReactJS (out of 3)                                                          0
# Other skills                Data Science, Machine Learning, Neural Network...
# Degree                                        Bachelor of Technology (B.Tech)
# Stream                                         Computer Science & Engineering
# Current Year Of Graduation                                               2019
# Performance_PG                                                            NaN
# Performance_UG                                                      85.50/100
# Performance_12                                                    92.20/92.20
# Performance_10                                                    96.60/96.60
#
#                                                                             2  \
# Application_ID                                                         ML0003
# Current City                                                        Bangalore
# Python (out of 3)                                                           3
# R Programming (out of 3)                                                    0
# Deep Learning (out of 3)                                                    1
# PHP (out of 3)                                                              2
# MySQL (out of 3)                                                            2
# HTML (out of 3)                                                             2
# CSS (out of 3)                                                              0
# JavaScript (out of 3)                                                       2
# Unnamed: 10                                                               NaN
# AJAX (out of 3)                                                             0
# Bootstrap (out of 3)                                                        0
# MongoDB (out of 3)                                                          0
# Node.js (out of 3)                                                          0
# ReactJS (out of 3)                                                          0
# Other skills                Algorithms, Data Structures, Python, C Program...
# Degree                                               Master of Science (M.Sc)
# Stream                                                      Computer  Science
# Current Year Of Graduation                                               2018
# Performance_PG                                                        7.91/10
# Performance_UG                                                      70.00/100
# Performance_12                                                    64.83/64.83
# Performance_10                                                    77.60/77.60
#
#                                                                             3  \
# Application_ID                                                         ML0004
# Current City                                                        Bangalore
# Python (out of 3)                                                           2
# R Programming (out of 3)                                                    0
# Deep Learning (out of 3)                                                    2
# PHP (out of 3)                                                              1
# MySQL (out of 3)                                                            0
# HTML (out of 3)                                                             2
# CSS (out of 3)                                                              0
# JavaScript (out of 3)                                                       0
# Unnamed: 10                                                               NaN
# AJAX (out of 3)                                                             0
# Bootstrap (out of 3)                                                        0
# MongoDB (out of 3)                                                          0
# Node.js (out of 3)                                                          0
# ReactJS (out of 3)                                                          0
# Other skills                CSS, Deep Learning, Embedded Systems, HTML, Ma...
# Degree                                          Bachelor of Engineering (B.E)
# Stream                                          Electronics and Communication
# Current Year Of Graduation                                               2019
# Performance_PG                                                            NaN
# Performance_UG                                                        6.86/10
# Performance_12                                                    76.00/76.00
# Performance_10                                                    84.32/84.32
#
#                                                                             4
# Application_ID                                                         ML0005
# Current City                                                        Bangalore
# Python (out of 3)                                                           2
# R Programming (out of 3)                                                    0
# Deep Learning (out of 3)                                                    0
# PHP (out of 3)                                                              2
# MySQL (out of 3)                                                            0
# HTML (out of 3)                                                             2
# CSS (out of 3)                                                              1
# JavaScript (out of 3)                                                       1
# Unnamed: 10                                                               NaN
# AJAX (out of 3)                                                             0
# Bootstrap (out of 3)                                                        0
# MongoDB (out of 3)                                                          2
# Node.js (out of 3)                                                          2
# ReactJS (out of 3)                                                          2
# Other skills                HTML, OpenCV, Python, SQL, C++ Programming, CS...
# Degree                                        Bachelor of Technology (B.Tech)
# Stream                                                 Production Engineering
# Current Year Of Graduation                                               2018
# Performance_PG                                                            NaN
# Performance_UG                                                        6.38/10
# Performance_12                                                    65.20/65.20
# Performance_10                                                    68.80/68.80

# %%
df.shape
# Out:
# (392, 24)

# %%
df.describe()
# Out:
#        Python (out of 3)  R Programming (out of 3)  Deep Learning (out of 3)  \
# count         392.000000                392.000000                392.000000
# mean            1.375000                  0.566327                  0.461735
# std             0.975237                  0.905052                  0.842336
# min             0.000000                  0.000000                  0.000000
# 25%             0.000000                  0.000000                  0.000000
# 50%             2.000000                  0.000000                  0.000000
# 75%             2.000000                  1.000000                  1.000000
# max             3.000000                  3.000000                  3.000000
#
#        PHP (out of 3)  MySQL (out of 3)  HTML (out of 3)  CSS (out of 3)  \
# count      392.000000        392.000000       392.000000      392.000000
# mean         0.612245          0.403061         1.346939        1.045918
# std          0.911789          0.837602         1.071386        1.022976
# min          0.000000          0.000000         0.000000        0.000000
# 25%          0.000000          0.000000         0.000000        0.000000
# 50%          0.000000          0.000000         2.000000        1.000000
# 75%          1.000000          0.000000         2.000000        2.000000
# max          3.000000          3.000000         3.000000        3.000000
#
#        JavaScript (out of 3)  Unnamed: 10  AJAX (out of 3)  \
# count             392.000000          0.0       392.000000
# mean                0.770408          NaN         0.015306
# std                 0.966626          NaN         0.122924
# min                 0.000000          NaN         0.000000
# 25%                 0.000000          NaN         0.000000
# 50%                 0.000000          NaN         0.000000
# 75%                 2.000000          NaN         0.000000
# max                 3.000000          NaN         1.000000
#
#        Bootstrap (out of 3)  MongoDB (out of 3)  Node.js (out of 3)  \
# count            392.000000          392.000000          392.000000
# mean               0.265306            0.035714            0.086735
# std                0.715928            0.255377            0.401567
# min                0.000000            0.000000            0.000000
# 25%                0.000000            0.000000            0.000000
# 50%                0.000000            0.000000            0.000000
# 75%                0.000000            0.000000            0.000000
# max                3.000000            2.000000            2.000000
#
#        ReactJS (out of 3)  Current Year Of Graduation
# count          392.000000                  392.000000
# mean             0.178571                 2018.867347
# std              0.499360                    2.280296
# min              0.000000                 2004.000000
# 25%              0.000000                 2018.750000
# 50%              0.000000                 2019.000000
# 75%              0.000000                 2020.000000
# max              2.000000                 2023.000000

# %%
df.describe(include = 'object')
# Out:
#        Application_ID Current City   Other skills  \
# count             392          392            378
# unique            392           63            313
# top            ML0255    Bangalore  Android, Java
# freq                1          214              4
#
#                                  Degree             Stream Performance_PG  \
# count                               380                374            103
# unique                               31                 78             66
# top     Bachelor of Technology (B.Tech)  Computer  Science        7.60/10
# freq                                110                 64              5
#
#        Performance_UG Performance_12 Performance_10
# count             338            229            215
# unique            173            143            108
# top         70.00/100    88.00/88.00    10.00/10.00
# freq               12              7              9

# %%
df.dtypes
# Out:
# Application_ID                 object
# Current City                   object
# Python (out of 3)               int64
# R Programming (out of 3)        int64
# Deep Learning (out of 3)        int64
# PHP (out of 3)                  int64
# MySQL (out of 3)                int64
# HTML (out of 3)                 int64
# CSS (out of 3)                  int64
# JavaScript (out of 3)           int64
# Unnamed: 10                   float64
# AJAX (out of 3)                 int64
# Bootstrap (out of 3)            int64
# MongoDB (out of 3)              int64
# Node.js (out of 3)              int64
# ReactJS (out of 3)              int64
# Other skills                   object
# Degree                         object
# Stream                         object
# Current Year Of Graduation      int64
# Performance_PG                 object
# Performance_UG                 object
# Performance_12                 object
# Performance_10                 object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Application_ID                  0
# Current City                    0
# Python (out of 3)               0
# R Programming (out of 3)        0
# Deep Learning (out of 3)        0
# PHP (out of 3)                  0
# MySQL (out of 3)                0
# HTML (out of 3)                 0
# CSS (out of 3)                  0
# JavaScript (out of 3)           0
# Unnamed: 10                   392
# AJAX (out of 3)                 0
# Bootstrap (out of 3)            0
# MongoDB (out of 3)              0
# Node.js (out of 3)              0
# ReactJS (out of 3)              0
# Other skills                   14
# Degree                         12
# Stream                         18
# Current Year Of Graduation      0
# Performance_PG                289
# Performance_UG                 54
# Performance_12                163
# Performance_10                177
# dtype: int64

# %%
pd.set_option('display.max_column',None)

# %%
df.head(3)
# Out:
#   Application_ID Current City  Python (out of 3)  R Programming (out of 3)  \
# 0         ML0001    Bangalore                  0                         2
# 1         ML0002    Bangalore                  2                         0
# 2         ML0003    Bangalore                  3                         0
#
#    Deep Learning (out of 3)  PHP (out of 3)  MySQL (out of 3)  \
# 0                         0               2                 0
# 1                         0               2                 2
# 2                         1               2                 2
#
#    HTML (out of 3)  CSS (out of 3)  JavaScript (out of 3)  Unnamed: 10  \
# 0                2               3                      2          NaN
# 1                2               2                      2          NaN
# 2                2               0                      2          NaN
#
#    AJAX (out of 3)  Bootstrap (out of 3)  MongoDB (out of 3)  \
# 0                0                     2                   0
# 1                0                     0                   0
# 2                0                     0                   0
#
#    Node.js (out of 3)  ReactJS (out of 3)  \
# 0                   0                   0
# 1                   0                   0
# 2                   0                   0
#
#                                         Other skills  \
# 0                                      R Programming
# 1  Data Science, Machine Learning, Neural Network...
# 2  Algorithms, Data Structures, Python, C Program...
#
#                             Degree                          Stream  \
# 0       Bachelor of Science (B.Sc)                     Mathematics
# 1  Bachelor of Technology (B.Tech)  Computer Science & Engineering
# 2         Master of Science (M.Sc)               Computer  Science
#
#    Current Year Of Graduation Performance_PG Performance_UG Performance_12  \
# 0                        2017            NaN            NaN            NaN
# 1                        2019            NaN      85.50/100    92.20/92.20
# 2                        2018        7.91/10      70.00/100    64.83/64.83
#
#   Performance_10
# 0            NaN
# 1    96.60/96.60
# 2    77.60/77.60

# %%
df['Degree'].value_counts()
# Out:
# Bachelor of Technology (B.Tech)                          110
# Bachelor of Engineering (B.E)                             84
# Master of Computer Applications (MCA)                     70
# B.Tech (Hons.)                                            25
# Master of Technology (M.Tech)                             19
# Master of Science (M.Sc)                                  14
# Bachelor of Computer Applications (BCA)                   10
# Post Graduate Programme (PGP)                              8
# Integrated M.Sc.                                           5
# Bachelor of Science (B.Sc)                                 5
# PG Diploma in Data Science                                 5
# Integrated B.Tech & M.Tech                                 2
# Bachelor of Commerce (B.Com)                               2
# Post Graduate Diploma in Management (P.G.D.M.)             2
# Integrated B.Tech                                          2
# MBA                                                        2
# Master of Science (M.Sc) (Hons.)                           1
# Bachelor of Commerce (B.Com) (Hons.)                       1
# Integrated M.Tech                                          1
# Bachelor of Computer Science (B.C.S.)                      1
# Master of Science (M.S.)                                   1
# Post Graduate Diploma                                      1
# Bachelor of Business Administration (B.B.A.)               1
# Bachelor of Engineering (B.E) (Hons.)                      1
# Integrated B.E & M.Tech                                    1
# Bachelor of Arts (B.A.) (Hons.)                            1
# Bachelor of Business Management (B.B.M.)                   1
# Post Graduate Diploma in Big Data Analytics (PG-DBDA)      1
# Executive MBA                                              1
# Post Graduate Program in Business Analytics                1
# B.Com. Professional                                        1
# Name: Degree, dtype: int64

# %%
df['Other skills'].value_counts().head(10)
# Out:
# Android, Java                                                                                                   4
# Data Analytics, Machine Learning, Python                                                                        4
# MS-Word, C Programming, CSS, Embedded Systems, HTML, JavaScript, MS-Excel, MS-Office, MS-PowerPoint, ReactJS    4
# C Programming, CSS, Database Management System (DBMS), HTML, Java, SQL, XML                                     3
# C Programming, Java, Python                                                                                     3
# Machine Learning, Python                                                                                        3
# CSS, HTML, Python, SQL, JavaScript                                                                              3
# HTML, Android, C Programming, C++ Programming, CSS, Java, PHP, Python                                           3
# C Programming, C++ Programming, Data Structures, HTML, Java, SQL, Android, C#, Python                           2
# Bootstrap, CSS, HTML, AngularJS, ElectronJS, JavaScript, Python, jQuery                                         2
# Name: Other skills, dtype: int64

# %%
df['Stream'].value_counts().head(15)
# Out:
# Computer  Science                                      64
# Electronics and Communication                          46
# Computer Science & Engineering                         45
# Computer Application                                   35
# Information Technology                                 20
# Mechanical Engineering                                 15
# computer science                                       11
# Data Science                                           10
# Electronics and Telecommunication Engineering (ETE)     8
# Electrical and Electronics Engineering                  7
# Mathematics                                             6
# MCA                                                     6
# Data Analytics                                          5
# IT                                                      5
# Business Analytics                                      4
# Name: Stream, dtype: int64

# %%
df['Current Year Of Graduation'].value_counts()
# Out:
# 2020    138
# 2019    108
# 2021     35
# 2018     29
# 2017     25
# 2016     18
# 2022     11
# 2015      9
# 2014      5
# 2013      4
# 2012      3
# 2023      2
# 2008      2
# 2007      1
# 2006      1
# 2004      1
# Name: Current Year Of Graduation, dtype: int64

# %%
df.drop('Unnamed: 10',axis = 1,inplace=True)

# %%
df.head(3)
# Out:
#   Application_ID Current City  Python (out of 3)  R Programming (out of 3)  \
# 0         ML0001    Bangalore                  0                         2
# 1         ML0002    Bangalore                  2                         0
# 2         ML0003    Bangalore                  3                         0
#
#    Deep Learning (out of 3)  PHP (out of 3)  MySQL (out of 3)  \
# 0                         0               2                 0
# 1                         0               2                 2
# 2                         1               2                 2
#
#    HTML (out of 3)  CSS (out of 3)  JavaScript (out of 3)  AJAX (out of 3)  \
# 0                2               3                      2                0
# 1                2               2                      2                0
# 2                2               0                      2                0
#
#    Bootstrap (out of 3)  MongoDB (out of 3)  Node.js (out of 3)  \
# 0                     2                   0                   0
# 1                     0                   0                   0
# 2                     0                   0                   0
#
#    ReactJS (out of 3)                                       Other skills  \
# 0                   0                                      R Programming
# 1                   0  Data Science, Machine Learning, Neural Network...
# 2                   0  Algorithms, Data Structures, Python, C Program...
#
#                             Degree                          Stream  \
# 0       Bachelor of Science (B.Sc)                     Mathematics
# 1  Bachelor of Technology (B.Tech)  Computer Science & Engineering
# 2         Master of Science (M.Sc)               Computer  Science
#
#    Current Year Of Graduation Performance_PG Performance_UG Performance_12  \
# 0                        2017            NaN            NaN            NaN
# 1                        2019            NaN      85.50/100    92.20/92.20
# 2                        2018        7.91/10      70.00/100    64.83/64.83
#
#   Performance_10
# 0            NaN
# 1    96.60/96.60
# 2    77.60/77.60

# %%
plt.subplots(figsize=(20,8))
sns.boxplot(data=df)

# %%
df.head()
# Out:
#   Application_ID Current City  Python (out of 3)  R Programming (out of 3)  \
# 0         ML0001    Bangalore                  0                         2
# 1         ML0002    Bangalore                  2                         0
# 2         ML0003    Bangalore                  3                         0
# 3         ML0004    Bangalore                  2                         0
# 4         ML0005    Bangalore                  2                         0
#
#    Deep Learning (out of 3)  PHP (out of 3)  MySQL (out of 3)  \
# 0                         0               2                 0
# 1                         0               2                 2
# 2                         1               2                 2
# 3                         2               1                 0
# 4                         0               2                 0
#
#    HTML (out of 3)  CSS (out of 3)  JavaScript (out of 3)  AJAX (out of 3)  \
# 0                2               3                      2                0
# 1                2               2                      2                0
# 2                2               0                      2                0
# 3                2               0                      0                0
# 4                2               1                      1                0
#
#    Bootstrap (out of 3)  MongoDB (out of 3)  Node.js (out of 3)  \
# 0                     2                   0                   0
# 1                     0                   0                   0
# 2                     0                   0                   0
# 3                     0                   0                   0
# 4                     0                   2                   2
#
#    ReactJS (out of 3)                                       Other skills  \
# 0                   0                                      R Programming
# 1                   0  Data Science, Machine Learning, Neural Network...
# 2                   0  Algorithms, Data Structures, Python, C Program...
# 3                   0  CSS, Deep Learning, Embedded Systems, HTML, Ma...
# 4                   2  HTML, OpenCV, Python, SQL, C++ Programming, CS...
#
#                             Degree                          Stream  \
# 0       Bachelor of Science (B.Sc)                     Mathematics
# 1  Bachelor of Technology (B.Tech)  Computer Science & Engineering
# 2         Master of Science (M.Sc)               Computer  Science
# 3    Bachelor of Engineering (B.E)   Electronics and Communication
# 4  Bachelor of Technology (B.Tech)          Production Engineering
#
#    Current Year Of Graduation Performance_PG Performance_UG Performance_12  \
# 0                        2017            NaN            NaN            NaN
# 1                        2019            NaN      85.50/100    92.20/92.20
# 2                        2018        7.91/10      70.00/100    64.83/64.83
# 3                        2019            NaN        6.86/10    76.00/76.00
# 4                        2018            NaN        6.38/10    65.20/65.20
#
#   Performance_10
# 0            NaN
# 1    96.60/96.60
# 2    77.60/77.60
# 3    84.32/84.32
# 4    68.80/68.80

# %%
df['Performance_PG'] = df['Performance_PG'].transform(lambda x: x.fillna('No degree'))

# %%
df1 = df['Performance_UG'].str.split('/',expand=True)
df2 = df['Performance_12'].str.split('/',expand=True)
df3 = df['Performance_10'].str.split('/',expand=True)

# %%
df1.drop(1,axis=1,inplace=True)
df2.drop(1,axis=1,inplace=True)
df3.drop(1,axis=1,inplace=True)

# %%
df1 = df1.rename(columns={0:'Performance_UG'})
df2 = df2.rename(columns={0:'Performance_12'})
df3 = df3.rename(columns={0:'Performance_10'})

# %%
df1.head(2)
# Out:
#   Performance_UG
# 0            NaN
# 1          85.50

# %%
df2.head(2)
# Out:
#   Performance_12
# 0            NaN
# 1          92.20

# %%
df3.head(2)
# Out:
#   Performance_10
# 0            NaN
# 1          96.60

# %%
scores = pd.concat([df1,df2,df3],axis=1)
scores.head(2)
# Out:
#   Performance_UG Performance_12 Performance_10
# 0            NaN            NaN            NaN
# 1          85.50          92.20          96.60

# %%
df.drop(['Performance_PG','Performance_UG','Performance_12','Performance_10'],axis=1,inplace=True)

# %%
data = pd.concat([df],axis=1)
data.head(2)
# Out:
#   Application_ID Current City  Python (out of 3)  R Programming (out of 3)  \
# 0         ML0001    Bangalore                  0                         2
# 1         ML0002    Bangalore                  2                         0
#
#    Deep Learning (out of 3)  PHP (out of 3)  MySQL (out of 3)  \
# 0                         0               2                 0
# 1                         0               2                 2
#
#    HTML (out of 3)  CSS (out of 3)  JavaScript (out of 3)  AJAX (out of 3)  \
# 0                2               3                      2                0
# 1                2               2                      2                0
#
#    Bootstrap (out of 3)  MongoDB (out of 3)  Node.js (out of 3)  \
# 0                     2                   0                   0
# 1                     0                   0                   0
#
#    ReactJS (out of 3)                                       Other skills  \
# 0                   0                                      R Programming
# 1                   0  Data Science, Machine Learning, Neural Network...
#
#                             Degree                          Stream  \
# 0       Bachelor of Science (B.Sc)                     Mathematics
# 1  Bachelor of Technology (B.Tech)  Computer Science & Engineering
#
#    Current Year Of Graduation
# 0                        2017
# 1                        2019

# %% [markdown]
# ####  categorical data must be converted to numbers through encoding

# %%
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

# %%
std = StandardScaler()

# %%
lable = preprocessing.LabelEncoder()

# %%
data['Other skills'] = data['Other skills'].transform(lambda x: x.fillna('unknown'))
data['Degree'] = data['Degree'].transform(lambda x: x.fillna('unknown'))
data['Stream'] = data['Stream'].transform(lambda x: x.fillna('unknown'))

# %%
df_labled = data.apply(lable.fit_transform)

# %%
df_scaled = std.fit_transform(df_labled)

# %%
df_scaled = pd.DataFrame(df_scaled,columns=data.columns)

# %%
df_scaled.head()
# Out:
#    Application_ID  Current City  Python (out of 3)  R Programming (out of 3)  \
# 0       -1.727638     -0.652202          -1.411716                  1.586103
# 1       -1.718801     -0.652202           0.641689                 -0.626539
# 2       -1.709964     -0.652202           1.668391                 -0.626539
# 3       -1.701127     -0.652202           0.641689                 -0.626539
# 4       -1.692290     -0.652202           0.641689                 -0.626539
#
#    Deep Learning (out of 3)  PHP (out of 3)  MySQL (out of 3)  \
# 0                 -0.548860        1.523959         -0.481824
# 1                 -0.548860        1.523959          1.908998
# 2                  0.639832        1.523959          1.908998
# 3                  1.828524        0.425812         -0.481824
# 4                 -0.548860        1.523959         -0.481824
#
#    HTML (out of 3)  CSS (out of 3)  JavaScript (out of 3)  AJAX (out of 3)  \
# 0         0.610327        1.912635               1.273671        -0.124676
# 1         0.610327        0.933845               1.273671        -0.124676
# 2         0.610327       -1.023734               1.273671        -0.124676
# 3         0.610327       -1.023734              -0.798026        -0.124676
# 4         0.610327       -0.044944               0.237822        -0.124676
#
#    Bootstrap (out of 3)  MongoDB (out of 3)  Node.js (out of 3)  \
# 0              2.426097           -0.140028           -0.216267
# 1             -0.371050           -0.140028           -0.216267
# 2             -0.371050           -0.140028           -0.216267
# 3             -0.371050           -0.140028           -0.216267
# 4             -0.371050            7.701540            4.770591
#
#    ReactJS (out of 3)  Other skills    Degree    Stream  \
# 0           -0.358057      1.563199 -0.445455  1.179256
# 1           -0.358057      0.386433 -0.307960 -0.714122
# 2           -0.358057     -1.378715  1.066988 -0.950794
# 3           -0.358057     -0.234043 -0.720445  0.232567
# 4            3.652186      0.932025 -0.307960  1.415928
#
#    Current Year Of Graduation
# 0                   -0.919900
# 1                    0.044273
# 2                   -0.437813
# 3                    0.044273
# 4                   -0.437813

# %% [markdown]
# ### Principal component analysis

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()
pc = pca.fit_transform(df_scaled)

# %%
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_ratio_, color='black')
plt.xlabel('PCA features')
plt.ylabel('variance %')
plt.xticks(features)
# Out:
# ([<matplotlib.axis.XTick at 0x19d7739be80>,
#   <matplotlib.axis.XTick at 0x19d7739b7f0>,
#   <matplotlib.axis.XTick at 0x19d7739b518>,
#   <matplotlib.axis.XTick at 0x19d773f16d8>,
#   <matplotlib.axis.XTick at 0x19d773f1b38>,
#   <matplotlib.axis.XTick at 0x19d773fc0b8>,
#   <matplotlib.axis.XTick at 0x19d773fc518>,
#   <matplotlib.axis.XTick at 0x19d773fca20>,
#   <matplotlib.axis.XTick at 0x19d773fce80>,
#   <matplotlib.axis.XTick at 0x19d77404550>,
#   <matplotlib.axis.XTick at 0x19d77404ac8>,
#   <matplotlib.axis.XTick at 0x19d7740b0f0>,
#   <matplotlib.axis.XTick at 0x19d77404518>,
#   <matplotlib.axis.XTick at 0x19d773fc5c0>,
#   <matplotlib.axis.XTick at 0x19d7740b518>,
#   <matplotlib.axis.XTick at 0x19d7740ba90>,
#   <matplotlib.axis.XTick at 0x19d774120b8>,
#   <matplotlib.axis.XTick at 0x19d774125c0>,
#   <matplotlib.axis.XTick at 0x19d77412b38>],
#  <a list of 19 Text xticklabel objects>)

# %%
pca = PCA(n_components=13)
pc = pca.fit_transform(df_scaled)

features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_ratio_, color='black')
plt.xlabel('PCA features')
plt.ylabel('variance %')
plt.xticks(features)
# Out:
# ([<matplotlib.axis.XTick at 0x19d77439630>,
#   <matplotlib.axis.XTick at 0x19d76ce2e10>,
#   <matplotlib.axis.XTick at 0x19d76ce2b38>,
#   <matplotlib.axis.XTick at 0x19d77497208>,
#   <matplotlib.axis.XTick at 0x19d77497668>,
#   <matplotlib.axis.XTick at 0x19d77497be0>,
#   <matplotlib.axis.XTick at 0x19d7749f198>,
#   <matplotlib.axis.XTick at 0x19d7749f710>,
#   <matplotlib.axis.XTick at 0x19d7749fc88>,
#   <matplotlib.axis.XTick at 0x19d7749fd68>,
#   <matplotlib.axis.XTick at 0x19d774974e0>,
#   <matplotlib.axis.XTick at 0x19d774a3550>,
#   <matplotlib.axis.XTick at 0x19d774a3ac8>],
#  <a list of 13 Text xticklabel objects>)

# %%
PCA_components = pd.DataFrame(pc,columns=['pc1','pc2','pc3','pc4','pc5','pc6','pc7','pc8','pc9','pc10','pc11','pc12','pc13'])

PCA_components.head()
# Out:
#         pc1       pc2       pc3       pc4       pc5       pc6       pc7  \
# 0  2.179485  1.479721 -1.057633  0.981028  0.606406 -1.359622 -1.148270
# 1  2.213445  0.920807 -1.102032  0.164471  0.313449  0.004669 -1.021800
# 2  1.589089  0.802380 -1.553413 -1.175338  0.054725  0.025918 -0.905842
# 3 -0.783494  1.019785 -0.387194 -1.450008  0.604404 -0.560720 -0.421505
# 4  3.612602  3.401630  6.783859 -1.066402 -2.739116  2.884280 -1.863911
#
#         pc8       pc9      pc10      pc11      pc12      pc13
# 0  1.963355 -1.096067 -0.044439  0.310292  1.139469 -1.068371
# 1 -1.426169 -0.258405 -0.177007 -0.796805 -0.690500  0.721063
# 2 -2.024896  0.989119  0.684116 -0.664592 -1.596665  1.432443
# 3 -1.456301  0.682155 -0.246440  1.326230  0.258349  0.473833
# 4  0.269821  2.131710  1.024482  1.594296  1.876221  0.007846

# %%
plt.subplots(figsize=(10,10))
sns.heatmap(PCA_components.corr(),square=True,annot=True)

# %% [markdown]
# ## start doing clustering by finding out optimal k value.¶

# %%
from sklearn.cluster import KMeans
cluster_range = range( 1, 15 )
cluster_errors = []
for num_clusters in cluster_range:
    clusters = KMeans( num_clusters,n_init = 15, random_state=2)
    clusters.fit(PCA_components)
    labels = clusters.labels_
    centroids = clusters.cluster_centers_
    cluster_errors.append( clusters.inertia_ )
clusters_df = pd.DataFrame( { "num_clusters":cluster_range, "cluster_errors": cluster_errors } )
clusters_df[0:15]
# Out:
#     num_clusters  cluster_errors
# 0              1     6513.487766
# 1              2     5566.918016
# 2              3     5017.440193
# 3              4     4713.731188
# 4              5     4319.124508
# 5              6     4014.501150
# 6              7     3756.361352
# 7              8     3520.903450
# 8              9     3355.010558
# 9             10     3224.956422
# 10            11     3087.570172
# 11            12     3024.618636
# 12            13     2918.080913
# 13            14     2828.151324

# %%
kmeans = KMeans(n_clusters=2, n_init = 15, random_state=2)

# %%
kmeans.fit(PCA_components)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=15, n_jobs=None, precompute_distances='auto',
#        random_state=2, tol=0.0001, verbose=0)

# %%
centroids=kmeans.cluster_centers_

# %%
centroid_df = pd.DataFrame(centroids, columns = list(PCA_components) )
centroid_df
# Out:
#         pc1       pc2       pc3       pc4       pc5       pc6       pc7  \
# 0  1.742251 -0.076648 -0.224581  0.221011 -0.034526 -0.119018  0.117021
# 1 -1.320361  0.058088  0.170198 -0.167493  0.026166  0.090197 -0.088684
#
#         pc8       pc9      pc10      pc11      pc12     pc13
# 0 -0.037678  0.030110 -0.033116  0.037161  0.100992 -0.04043
# 1  0.028554 -0.022819  0.025097 -0.028162 -0.076536  0.03064

# %%
df_labels = pd.DataFrame(kmeans.labels_ , columns = list(['labels']))

df_labels['labels'] = df_labels['labels'].astype('category')

selection_df_labeled = PCA_components.join(df_labels)
selection_clusters = selection_df_labeled.groupby(['labels'])
#wine_clusters = wine_data_attr.groupby(['clusters'])
df0=selection_clusters.get_group(0)
df1=selection_clusters.get_group(1)
finaldf = pd.concat([df0,df1])
finaldf.head()
# Out:
#         pc1       pc2       pc3       pc4       pc5       pc6       pc7  \
# 0  2.179485  1.479721 -1.057633  0.981028  0.606406 -1.359622 -1.148270
# 1  2.213445  0.920807 -1.102032  0.164471  0.313449  0.004669 -1.021800
# 2  1.589089  0.802380 -1.553413 -1.175338  0.054725  0.025918 -0.905842
# 4  3.612602  3.401630  6.783859 -1.066402 -2.739116  2.884280 -1.863911
# 5  1.194632  1.155275 -2.043367  0.598529 -0.671965  1.427305 -1.092893
#
#         pc8       pc9      pc10      pc11      pc12      pc13 labels
# 0  1.963355 -1.096067 -0.044439  0.310292  1.139469 -1.068371      0
# 1 -1.426169 -0.258405 -0.177007 -0.796805 -0.690500  0.721063      0
# 2 -2.024896  0.989119  0.684116 -0.664592 -1.596665  1.432443      0
# 4  0.269821  2.131710  1.024482  1.594296  1.876221  0.007846      0
# 5 -0.817130  0.217422  0.147683  0.837669 -0.092492 -0.533037      0

# %%
final_data = pd.concat([df_labled,finaldf['labels']],axis=1)
final_data.head()
# Out:
#    Application_ID  Current City  Python (out of 3)  R Programming (out of 3)  \
# 0               0             4                  0                         2
# 1               1             4                  2                         0
# 2               2             4                  3                         0
# 3               3             4                  2                         0
# 4               4             4                  2                         0
#
#    Deep Learning (out of 3)  PHP (out of 3)  MySQL (out of 3)  \
# 0                         0               2                 0
# 1                         0               2                 2
# 2                         1               2                 2
# 3                         2               1                 0
# 4                         0               2                 0
#
#    HTML (out of 3)  CSS (out of 3)  JavaScript (out of 3)  AJAX (out of 3)  \
# 0                2               3                      2                0
# 1                2               2                      2                0
# 2                2               0                      2                0
# 3                2               0                      0                0
# 4                2               1                      1                0
#
#    Bootstrap (out of 3)  MongoDB (out of 3)  Node.js (out of 3)  \
# 0                     2                   0                   0
# 1                     0                   0                   0
# 2                     0                   0                   0
# 3                     0                   0                   0
# 4                     0                   2                   2
#
#    ReactJS (out of 3)  Other skills  Degree  Stream  \
# 0                   0           303      11      62
# 1                   0           193      12      22
# 2                   0            28      22      17
# 3                   0           135       9      42
# 4                   2           244      12      67
#
#    Current Year Of Graduation labels
# 0                           9      0
# 1                          11      0
# 2                          10      0
# 3                          11      1
# 4                          10      0

# %% [markdown]
# ### no we can use classification techniques to predict the target variable.

# %%
from sklearn.linear_model import LogisticRegressionCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier

# %%
x = final_data.drop(['Application_ID','labels'],axis=1)
y = final_data['labels']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=1)

# %%
array = [LogisticRegressionCV(),
        DecisionTreeClassifier(),
        RandomForestClassifier(n_estimators=50,n_jobs=5),
        AdaBoostClassifier(),
        GradientBoostingClassifier()]

# %%
for i in range (0,len(array)):
    array[i].fit(x_train,y_train)
# Out:
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\shishir kumar thakur\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score,classification_report

# %%
l=[]
for i in range (0,len(array)):
    y_pred=array[i].predict(x_test)
    l.append(accuracy_score(y_pred,y_test))
print(l)
# Out:
# [0.9915254237288136, 0.9661016949152542, 0.9830508474576272, 0.9830508474576272, 0.9830508474576272]

# %%
final = pd.DataFrame(l,index=('Logistic regreesion','Decision tree','Randomforest','Ada boost','Gradient boost'),columns=['Accuracy score'])
final
# Out:
#                      Accuracy score
# Logistic regreesion        0.991525
# Decision tree              0.966102
# Randomforest               0.983051
# Ada boost                  0.983051
# Gradient boost             0.983051

# %%
rf = RandomForestClassifier(n_estimators=50,n_jobs=5)
rf_model = rf.fit(x_train,y_train)
rf_model
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=5,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)

# %%
y_pred = rf.predict(x_test)

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97        49
#            1       0.97      0.99      0.98        69
#
#     accuracy                           0.97       118
#    macro avg       0.98      0.97      0.97       118
# weighted avg       0.97      0.97      0.97       118
